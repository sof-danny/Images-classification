# %% [markdown]
# # Assignment 3 Part 1: Developing Your Own Classifier

# %%
 # !sh download_data.sh
# Out:
# --2022-03-20 12:11:49--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar.1’
#
# VOCtrainval_06-Nov-  62%[===========>        ] 274.33M   272KB/s    in 19m 0s
#
# 2022-03-20 12:30:49 (246 KB/s) - Connection closed at byte 287659377. Retrying.
#
# --2022-03-20 12:30:50--  (try: 2)  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 460032000 (439M), 172372623 (164M) remaining [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar.1’
#
# VOCtrainval_06-Nov- 100%[++++++++++++=======>] 438.72M  1.35MB/s    in 2m 26s
#
# 2022-03-20 12:33:16 (1.12 MB/s) - ‘VOCtrainval_06-Nov-2007.tar.1’ saved [460032000/460032000]
#
# mv: rename VOCdevkit to VOCdevkit_2007/VOCdevkit: Directory not empty
# --2022-03-20 12:33:18--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  3.05MB/s    in 5m 21s
#
# 2022-03-20 12:38:39 (1.34 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/samuel/opt/anaconda3/lib/python3.8/site-packages (21.3.1)
# Collecting pip
#   Using cached pip-22.0.4-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.3.1
#     Uninstalling pip-21.3.1:
#       Successfully uninstalled pip-21.3.1
# Successfully installed pip-22.0.4

# %%
# !pip3 install torch
# Out:
# Collecting torch
#   Using cached torch-1.11.0-cp39-none-macosx_10_9_x86_64.whl (129.9 MB)
# Requirement already satisfied: typing-extensions in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from torch) (3.10.0.2)
# Installing collected packages: torch
# Successfully installed torch-1.11.0

# %%
# !pip3 install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.12.0-cp39-cp39-macosx_10_9_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 7.0 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from torchvision) (3.10.0.2)
# Requirement already satisfied: requests in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from torchvision) (2.26.0)
# Requirement already satisfied: numpy in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from torchvision) (1.20.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: torch==1.11.0 in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from torchvision) (1.11.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (1.26.7)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.12.0

# %%
# !pip3 install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.64-cp36-abi3-macosx_10_15_x86_64.whl (46.3 MB)
#      |████████████████████████████████| 46.3 MB 5.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /Users/samuel/opt/anaconda3/lib/python3.9/site-packages (from opencv-python) (1.20.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Part 1B: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        scheduler.step()
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            print("mAp for Training on Epoch" + str(epoch) + "is" + str(mAP_train))
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

ds_train = VocDataset('VOCdevkit_2007/VOC2007/','train',train_transform)
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)
# Out:
# /Users/samuel/SP22/CS444/assignment3_part1/voc_dataloader.py:137: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(box_indices),

# %%
num_epochs = 50
test_frequency = 5
batch_size = 62

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=1)

# %%
# TODO: Run your own classifier here
classifier = Classifier().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.0001, momentum=0.9)
# optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)
scheduler =torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones =[2,4], gamma=10)
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.3336406648159027
# -------  Class: aeroplane        AP:   0.0347  -------
# -------  Class: bicycle          AP:   0.0820  -------
# -------  Class: bird             AP:   0.0860  -------
# -------  Class: boat             AP:   0.0304  -------
# -------  Class: bottle           AP:   0.0630  -------
# -------  Class: bus              AP:   0.0577  -------
# -------  Class: car              AP:   0.1875  -------
# -------  Class: cat              AP:   0.0554  -------
# -------  Class: chair            AP:   0.1387  -------
# -------  Class: cow              AP:   0.0352  -------
# -------  Class: diningtable      AP:   0.0803  -------
# -------  Class: dog              AP:   0.0749  -------
# -------  Class: horse            AP:   0.0906  -------
# -------  Class: motorbike        AP:   0.0879  -------
# -------  Class: person           AP:   0.4999  -------
# -------  Class: pottedplant      AP:   0.0922  -------
# -------  Class: sheep            AP:   0.0175  -------
# -------  Class: sofa             AP:   0.0686  -------
# -------  Class: train            AP:   0.0835  -------
# -------  Class: tvmonitor        AP:   0.0488  -------
# mAP: 0.0957
# Avg loss: 0.23396881651587603
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.09574252742433767
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.2409650683403015
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.2350614368915558
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.2293667048215866
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.2240140289068222
# -------  Class: aeroplane        AP:   0.4491  -------
# -------  Class: bicycle          AP:   0.1457  -------
# -------  Class: bird             AP:   0.1549  -------
# -------  Class: boat             AP:   0.1742  -------
# -------  Class: bottle           AP:   0.1185  -------
# -------  Class: bus              AP:   0.1272  -------
# -------  Class: car              AP:   0.3099  -------
# -------  Class: cat              AP:   0.2309  -------
# -------  Class: chair            AP:   0.2606  -------
# -------  Class: cow              AP:   0.0528  -------
# -------  Class: diningtable      AP:   0.2214  -------
# -------  Class: dog              AP:   0.1779  -------
# -------  Class: horse            AP:   0.1149  -------
# -------  Class: motorbike        AP:   0.1559  -------
# -------  Class: person           AP:   0.5722  -------
# -------  Class: pottedplant      AP:   0.1181  -------
# -------  Class: sheep            AP:   0.0835  -------
# -------  Class: sofa             AP:   0.1859  -------
# -------  Class: train            AP:   0.2132  -------
# -------  Class: tvmonitor        AP:   0.1083  -------
# mAP: 0.1988
# Avg loss: 0.21408392961432293
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.19875263833668477
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.21775266528129578
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.2120821475982666
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.20745936036109924
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.20411039888858795
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.1987251490354538
# -------  Class: aeroplane        AP:   0.4828  -------
# -------  Class: bicycle          AP:   0.2156  -------
# -------  Class: bird             AP:   0.1781  -------
# -------  Class: boat             AP:   0.2467  -------
# -------  Class: bottle           AP:   0.1202  -------
# -------  Class: bus              AP:   0.1333  -------
# -------  Class: car              AP:   0.4096  -------
# -------  Class: cat              AP:   0.2648  -------
# -------  Class: chair            AP:   0.3281  -------
# -------  Class: cow              AP:   0.0976  -------
# -------  Class: diningtable      AP:   0.2566  -------
# -------  Class: dog              AP:   0.1940  -------
# -------  Class: horse            AP:   0.3438  -------
# -------  Class: motorbike        AP:   0.1890  -------
# -------  Class: person           AP:   0.6367  -------
# -------  Class: pottedplant      AP:   0.1305  -------
# -------  Class: sheep            AP:   0.1583  -------
# -------  Class: sofa             AP:   0.2142  -------
# -------  Class: train            AP:   0.2649  -------
# -------  Class: tvmonitor        AP:   0.1639  -------
# mAP: 0.2514
# Avg loss: 0.19997767886010612
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.2514427679068958
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.1981394737958908
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.19222252070903778
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.18842609226703644
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.18653592467308044
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.1831602156162262
# -------  Class: aeroplane        AP:   0.5284  -------
# -------  Class: bicycle          AP:   0.2502  -------
# -------  Class: bird             AP:   0.1712  -------
# -------  Class: boat             AP:   0.2989  -------
# -------  Class: bottle           AP:   0.1273  -------
# -------  Class: bus              AP:   0.1757  -------
# -------  Class: car              AP:   0.4909  -------
# -------  Class: cat              AP:   0.3012  -------
# -------  Class: chair            AP:   0.3720  -------
# -------  Class: cow              AP:   0.1208  -------
# -------  Class: diningtable      AP:   0.2733  -------
# -------  Class: dog              AP:   0.2306  -------
# -------  Class: horse            AP:   0.4177  -------
# -------  Class: motorbike        AP:   0.2390  -------
# -------  Class: person           AP:   0.6872  -------
# -------  Class: pottedplant      AP:   0.1494  -------
# -------  Class: sheep            AP:   0.1887  -------
# -------  Class: sofa             AP:   0.2163  -------
# -------  Class: train            AP:   0.3588  -------
# -------  Class: tvmonitor        AP:   0.2149  -------
# mAP: 0.2906
# Avg loss: 0.19316450015800754
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.29062355029626236
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.17694304883480072
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.1734808385372162
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.17099173367023468
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.1670491248369217
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.1640433967113495
# -------  Class: aeroplane        AP:   0.5641  -------
# -------  Class: bicycle          AP:   0.3049  -------
# -------  Class: bird             AP:   0.1865  -------
# -------  Class: boat             AP:   0.3281  -------
# -------  Class: bottle           AP:   0.1191  -------
# -------  Class: bus              AP:   0.1978  -------
# -------  Class: car              AP:   0.5329  -------
# -------  Class: cat              AP:   0.3563  -------
# -------  Class: chair            AP:   0.3974  -------
# -------  Class: cow              AP:   0.1275  -------
# -------  Class: diningtable      AP:   0.2876  -------
# -------  Class: dog              AP:   0.2496  -------
# -------  Class: horse            AP:   0.4454  -------
# -------  Class: motorbike        AP:   0.2833  -------
# -------  Class: person           AP:   0.7087  -------
# -------  Class: pottedplant      AP:   0.1863  -------
# -------  Class: sheep            AP:   0.1971  -------
# -------  Class: sofa             AP:   0.2288  -------
# -------  Class: train            AP:   0.4198  -------
# -------  Class: tvmonitor        AP:   0.2731  -------
# mAP: 0.3197
# Avg loss: 0.18876754619726321
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.3197169749753458
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.16054698824882507
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.15494561195373535
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.15042930841445923
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.14757777750492096
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.14164485037326813
# -------  Class: aeroplane        AP:   0.5811  -------
# -------  Class: bicycle          AP:   0.3086  -------
# -------  Class: bird             AP:   0.2093  -------
# -------  Class: boat             AP:   0.3399  -------
# -------  Class: bottle           AP:   0.1280  -------
# -------  Class: bus              AP:   0.2890  -------
# -------  Class: car              AP:   0.5409  -------
# -------  Class: cat              AP:   0.3482  -------
# -------  Class: chair            AP:   0.3928  -------
# -------  Class: cow              AP:   0.1365  -------
# -------  Class: diningtable      AP:   0.3020  -------
# -------  Class: dog              AP:   0.2617  -------
# -------  Class: horse            AP:   0.4769  -------
# -------  Class: motorbike        AP:   0.3367  -------
# -------  Class: person           AP:   0.7302  -------
# -------  Class: pottedplant      AP:   0.1598  -------
# -------  Class: sheep            AP:   0.2060  -------
# -------  Class: sofa             AP:   0.2563  -------
# -------  Class: train            AP:   0.4487  -------
# -------  Class: tvmonitor        AP:   0.2695  -------
# mAP: 0.3361
# Avg loss: 0.19682833879459194
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.3360993799904359
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.13718268275260925
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.13206876814365387
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.126864492893219
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.1242804303765297
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.11764005571603775
# -------  Class: aeroplane        AP:   0.5850  -------
# -------  Class: bicycle          AP:   0.3203  -------
# -------  Class: bird             AP:   0.2118  -------
# -------  Class: boat             AP:   0.3724  -------
# -------  Class: bottle           AP:   0.1396  -------
# -------  Class: bus              AP:   0.3036  -------
# -------  Class: car              AP:   0.5437  -------
# -------  Class: cat              AP:   0.3682  -------
# -------  Class: chair            AP:   0.4135  -------
# -------  Class: cow              AP:   0.1505  -------
# -------  Class: diningtable      AP:   0.3266  -------
# -------  Class: dog              AP:   0.2699  -------
# -------  Class: horse            AP:   0.5115  -------
# -------  Class: motorbike        AP:   0.3561  -------
# -------  Class: person           AP:   0.7082  -------
# -------  Class: pottedplant      AP:   0.2121  -------
# -------  Class: sheep            AP:   0.1989  -------
# -------  Class: sofa             AP:   0.2633  -------
# -------  Class: train            AP:   0.5040  -------
# -------  Class: tvmonitor        AP:   0.2893  -------
# mAP: 0.3524
# Avg loss: 0.19791123598087124
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.35243521819182894
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.1128690093755722
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.10791560262441635
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.10354174673557281
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.09635566174983978
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.09241657704114914
# -------  Class: aeroplane        AP:   0.5974  -------
# -------  Class: bicycle          AP:   0.3127  -------
# -------  Class: bird             AP:   0.2407  -------
# -------  Class: boat             AP:   0.4293  -------
# -------  Class: bottle           AP:   0.1363  -------
# -------  Class: bus              AP:   0.2830  -------
# -------  Class: car              AP:   0.5521  -------
# -------  Class: cat              AP:   0.3859  -------
# -------  Class: chair            AP:   0.4021  -------
# -------  Class: cow              AP:   0.1405  -------
# -------  Class: diningtable      AP:   0.3344  -------
# -------  Class: dog              AP:   0.2928  -------
# -------  Class: horse            AP:   0.5169  -------
# -------  Class: motorbike        AP:   0.3575  -------
# -------  Class: person           AP:   0.7045  -------
# -------  Class: pottedplant      AP:   0.2111  -------
# -------  Class: sheep            AP:   0.1924  -------
# -------  Class: sofa             AP:   0.2439  -------
# -------  Class: train            AP:   0.5488  -------
# -------  Class: tvmonitor        AP:   0.3026  -------
# mAP: 0.3593
# Avg loss: 0.20209288124631092
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.35925090040546437
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.0895632654428482
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.08489879220724106
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.07880132645368576
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.07461920380592346
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.07161280512809753
# -------  Class: aeroplane        AP:   0.6074  -------
# -------  Class: bicycle          AP:   0.3610  -------
# -------  Class: bird             AP:   0.2265  -------
# -------  Class: boat             AP:   0.4360  -------
# -------  Class: bottle           AP:   0.1357  -------
# -------  Class: bus              AP:   0.2969  -------
# -------  Class: car              AP:   0.5365  -------
# -------  Class: cat              AP:   0.3422  -------
# -------  Class: chair            AP:   0.3968  -------
# -------  Class: cow              AP:   0.1532  -------
# -------  Class: diningtable      AP:   0.2877  -------
# -------  Class: dog              AP:   0.2600  -------
# -------  Class: horse            AP:   0.5111  -------
# -------  Class: motorbike        AP:   0.4094  -------
# -------  Class: person           AP:   0.7255  -------
# -------  Class: pottedplant      AP:   0.2267  -------
# -------  Class: sheep            AP:   0.2065  -------
# -------  Class: sofa             AP:   0.2474  -------
# -------  Class: train            AP:   0.5250  -------
# -------  Class: tvmonitor        AP:   0.3082  -------
# mAP: 0.3600
# Avg loss: 0.20777892375864634
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.3599847348309619
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.06753599643707275
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.06401079148054123
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.05953091382980347
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.053886063396930695
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.05207723006606102
# -------  Class: aeroplane        AP:   0.5951  -------
# -------  Class: bicycle          AP:   0.3509  -------
# -------  Class: bird             AP:   0.2045  -------
# -------  Class: boat             AP:   0.4185  -------
# -------  Class: bottle           AP:   0.1201  -------
# -------  Class: bus              AP:   0.2880  -------
# -------  Class: car              AP:   0.5376  -------
# -------  Class: cat              AP:   0.3687  -------
# -------  Class: chair            AP:   0.3908  -------
# -------  Class: cow              AP:   0.1597  -------
# -------  Class: diningtable      AP:   0.3262  -------
# -------  Class: dog              AP:   0.2717  -------
# -------  Class: horse            AP:   0.5066  -------
# -------  Class: motorbike        AP:   0.3933  -------
# -------  Class: person           AP:   0.7091  -------
# -------  Class: pottedplant      AP:   0.2034  -------
# -------  Class: sheep            AP:   0.2161  -------
# -------  Class: sofa             AP:   0.2223  -------
# -------  Class: train            AP:   0.5116  -------
# -------  Class: tvmonitor        AP:   0.2653  -------
# mAP: 0.3530
# Avg loss: 0.23196079236705128
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.3529762251893777
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.04942309111356735
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.04613375663757324
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.042622532695531845
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.03841670975089073
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.03451167792081833
# -------  Class: aeroplane        AP:   0.6089  -------
# -------  Class: bicycle          AP:   0.3618  -------
# -------  Class: bird             AP:   0.1976  -------
# -------  Class: boat             AP:   0.3930  -------
# -------  Class: bottle           AP:   0.1213  -------
# -------  Class: bus              AP:   0.2770  -------
# -------  Class: car              AP:   0.5249  -------
# -------  Class: cat              AP:   0.3439  -------
# -------  Class: chair            AP:   0.3983  -------
# -------  Class: cow              AP:   0.1435  -------
# -------  Class: diningtable      AP:   0.3404  -------
# -------  Class: dog              AP:   0.2680  -------
# -------  Class: horse            AP:   0.4985  -------
# -------  Class: motorbike        AP:   0.4175  -------
# -------  Class: person           AP:   0.7060  -------
# -------  Class: pottedplant      AP:   0.1873  -------
# -------  Class: sheep            AP:   0.1717  -------
# -------  Class: sofa             AP:   0.2448  -------
# -------  Class: train            AP:   0.5198  -------
# -------  Class: tvmonitor        AP:   0.2718  -------
# mAP: 0.3498
# Avg loss: 0.2312778379858994
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.3498120224165051

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/qx/_v9f4zgd6f1d2hx2z4pcrxqm0000gp/T/ipykernel_35811/1446557333.py in <module>
# ----> 1 mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
#       2 print(mAP_test)
#
# /var/folders/qx/_v9f4zgd6f1d2hx2z4pcrxqm0000gp/T/ipykernel_35811/2631065700.py in test_classifier(test_loader, classifier, criterion, print_ind_classes, print_total)
#       5         y_true = np.zeros((0,21))
#       6         y_score = np.zeros((0,21))
# ----> 7         for i, (images, labels) in enumerate(test_loader):
#       8             images, labels = images.to(device), labels.to(device)
#       9             logits = classifier(images)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1222             else:
#    1223                 del self._task_info[idx]
# -> 1224                 return self._process_data(data)
#    1225
#    1226     def _try_put_index(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1248         self._try_put_index()
#    1249         if isinstance(data, ExceptionWrapper):
# -> 1250             data.reraise()
#    1251         return data
#    1252
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/_utils.py in reraise(self)
#     455             # instantiate since we don't know how to
#     456             raise RuntimeError(msg) from None
# --> 457         raise exception
#     458
#     459
#
# OSError: Caught OSError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/worker.py", line 287, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 49, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 49, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/Users/samuel/SP22/CS444/assignment3_part1/voc_dataloader.py", line 72, in __getitem__
#     x = self.transform(x)
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/transforms.py", line 95, in __call__
#     img = t(img)
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1110, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/transforms.py", line 349, in forward
#     return F.resize(img, self.size, self.interpolation, self.max_size, self.antialias)
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py", line 436, in resize
#     return F_pil.resize(img, size=size, interpolation=pil_interpolation, max_size=max_size)
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional_pil.py", line 258, in resize
#     return img.resize((new_w, new_h), interpolation)
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py", line 1989, in resize
#     self.load()
#   File "/Users/samuel/opt/anaconda3/lib/python3.9/site-packages/PIL/ImageFile.py", line 249, in load
#     raise OSError(
# OSError: image file is truncated (66 bytes not processed)

# %%
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('my_solution.csv', test_aps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qx/_v9f4zgd6f1d2hx2z4pcrxqm0000gp/T/ipykernel_28454/718174793.py in <module>
#       1 torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
# ----> 2 output_submission_csv('my_solution.csv', test_aps)
#
# NameError: name 'test_aps' is not defined

# %%
"""This is the main file we need to run"""
